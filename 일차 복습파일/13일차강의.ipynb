# %% [markdown]
# ## 13일차 강의 (2021.7.21)
# # 파이썬 데이터분석

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
data = pd.DataFrame([['홍길동',99,'1999/1/1'],
                     ['장길산',88,'1987/3/1'],
                     ['둘리',51,'2005/5/5']],
                   columns=['이름','성적','생일'])
data
# Out:
#     이름  성적        생일
# 0  홍길동  99  1999/1/1
# 1  장길산  88  1987/3/1
# 2   둘리  51  2005/5/5

# %%
data.이름.map(lambda s: s[1:])
# Out:
# 0    길동
# 1    길산
# 2     리
# Name: 이름, dtype: object

# %%
data['이름부분'] = data.이름.map(lambda s: s[1:])

# %%
data
# Out:
#     이름  성적        생일 이름부분
# 0  홍길동  99  1999/1/1   길동
# 1  장길산  88  1987/3/1   길산
# 2   둘리  51  2005/5/5    리

# %%
data['성'] = data.이름.map(lambda s: s[0] if len(s)==3 else '김')
data
# Out:
#     이름  성적        생일 이름부분  성
# 0  홍길동  99  1999/1/1   길동  홍
# 1  장길산  88  1987/3/1   길산  장
# 2   둘리  51  2005/5/5    리  김

# %%
data.이름.str[0]
# Out:
# 0    홍
# 1    장
# 2    둘
# Name: 이름, dtype: object

# %%
data.이름.str[1:]
# Out:
# 0    길동
# 1    길산
# 2     리
# Name: 이름, dtype: object

# %%
dir('')
# Out:
# ['__add__',
#  '__class__',
#  '__contains__',
#  '__delattr__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__getitem__',
#  '__getnewargs__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__iter__',
#  '__le__',
#  '__len__',
#  '__lt__',
#  '__mod__',
#  '__mul__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__rmod__',
#  '__rmul__',
#  '__setattr__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  'capitalize',
#  'casefold',
#  'center',
#  'count',
#  'encode',
#  'endswith',
#  'expandtabs',
#  'find',
#  'format',
#  'format_map',
#  'index',
#  'isalnum',
#  'isalpha',
#  'isascii',
#  'isdecimal',
#  'isdigit',
#  'isidentifier',
#  'islower',
#  'isnumeric',
#  'isprintable',
#  'isspace',
#  'istitle',
#  'isupper',
#  'join',
#  'ljust',
#  'lower',
#  'lstrip',
#  'maketrans',
#  'partition',
#  'replace',
#  'rfind',
#  'rindex',
#  'rjust',
# ...

# %%
a = np.random.randint(10, size=[10,10])

# %%
a
# Out:
# array([[3, 0, 9, 7, 4, 1, 7, 1, 2, 6],
#        [0, 4, 8, 7, 0, 8, 8, 6, 1, 2],
#        [1, 7, 6, 7, 2, 5, 1, 1, 4, 7],
#        [7, 9, 4, 1, 8, 7, 7, 6, 3, 4],
#        [4, 6, 9, 4, 0, 9, 2, 5, 4, 7],
#        [8, 0, 0, 1, 9, 3, 6, 2, 4, 1],
#        [4, 7, 7, 3, 5, 7, 5, 3, 3, 2],
#        [3, 8, 5, 8, 9, 3, 0, 0, 3, 5],
#        [8, 9, 5, 1, 7, 2, 4, 3, 2, 8],
#        [7, 1, 3, 8, 4, 6, 1, 7, 3, 7]])

# %%
a[a[:,0]>5]
# Out:
# array([[7, 9, 4, 1, 8, 7, 7, 6, 3, 4],
#        [8, 0, 0, 1, 9, 3, 6, 2, 4, 1],
#        [8, 9, 5, 1, 7, 2, 4, 3, 2, 8],
#        [7, 1, 3, 8, 4, 6, 1, 7, 3, 7]])

# %%
data
# Out:
#     이름  성적        생일 이름부분  성
# 0  홍길동  99  1999/1/1   길동  홍
# 1  장길산  88  1987/3/1   길산  장
# 2   둘리  51  2005/5/5    리  김

# %%
data[data.이름>'라']
# Out:
#     이름  성적        생일 이름부분  성
# 0  홍길동  99  1999/1/1   길동  홍
# 1  장길산  88  1987/3/1   길산  장

# %%
data[(data.이름>'라') & (data.성적>90)]
# Out:
#     이름  성적        생일 이름부분  성
# 0  홍길동  99  1999/1/1   길동  홍

# %%
data['날자'] = pd.to_datetime(data.생일)
data
# Out:
#     이름  성적        생일 이름부분  성         날자
# 0  홍길동  99  1999/1/1   길동  홍 1999-01-01
# 1  장길산  88  1987/3/1   길산  장 1987-03-01
# 2   둘리  51  2005/5/5    리  김 2005-05-05

# %%
data[data.날자.dt.dayofweek>4]
# Out:
#     이름  성적        생일 이름부분  성         날자
# 1  장길산  88  1987/3/1   길산  장 1987-03-01

# %%
data[data.이름.map(len)<3]
# Out:
#    이름  성적        생일 이름부분  성         날자
# 2  둘리  51  2005/5/5    리  김 2005-05-05

# %%
data = pd.DataFrame([[99,88,'서울'], [76,89,'부산'],
                    [86,95,'원주'], [63,76,'서울']],
                   columns=['국어','영어','지역'])
data
# Out:
#    국어  영어  지역
# 0  99  88  서울
# 1  76  89  부산
# 2  86  95  원주
# 3  63  76  서울

# %%
data.지역.value_counts()
# Out:
# 서울    2
# 원주    1
# 부산    1
# Name: 지역, dtype: int64

# %%
list(data.지역.value_counts().index)
# Out:
# ['서울', '원주', '부산']

# %%
a = np.random.randint(1,7, size=100000)
pd.value_counts(a)
# Out:
# 6    16798
# 1    16752
# 4    16669
# 3    16669
# 2    16652
# 5    16460
# dtype: int64

# %%
s = pd.value_counts(a).sort_index()
plt.ylim(0,17000)
plt.plot(s.index, s, 'ro-')

# %% [markdown]
# ### 연습문제
# - 행복지수 데이터에서 각 지역별 나라 갯수를 구하시오.
# - 지수 구간별 나라 갯수를 구하시오. (7.xx 이면 7로 계산)

# %%
happy = pd.read_csv('world_happiness_report_2021.csv')
happy.head()
# Out:
#   Country name Regional indicator  Ladder score  \
# 0      Finland     Western Europe         7.842
# 1      Denmark     Western Europe         7.620
# 2  Switzerland     Western Europe         7.571
# 3      Iceland     Western Europe         7.554
# 4  Netherlands     Western Europe         7.464
#
#    Standard error of ladder score  upperwhisker  lowerwhisker  \
# 0                           0.032         7.904         7.780
# 1                           0.035         7.687         7.552
# 2                           0.036         7.643         7.500
# 3                           0.059         7.670         7.438
# 4                           0.027         7.518         7.410
#
#    Logged GDP per capita  Social support  Healthy life expectancy  \
# 0                 10.775           0.954                     72.0
# 1                 10.933           0.954                     72.7
# 2                 11.117           0.942                     74.4
# ...

# %%
happy['Regional indicator'].value_counts()
# Out:
# Sub-Saharan Africa                    36
# Western Europe                        21
# Latin America and Caribbean           20
# Central and Eastern Europe            17
# Middle East and North Africa          17
# Commonwealth of Independent States    12
# Southeast Asia                         9
# South Asia                             7
# East Asia                              6
# North America and ANZ                  4
# Name: Regional indicator, dtype: int64

# %%
np.floor(happy['Ladder score']).value_counts().sort_index()
# Out:
# 2.0     1
# 3.0    11
# 4.0    36
# 5.0    49
# 6.0    35
# 7.0    17
# Name: Ladder score, dtype: int64

# %%
ls = happy['Ladder score']
for i in range(8):
    n = ((ls>=i) & (ls<i+1)).sum()
    print(i, n)
# Out:
# 0 0
# 1 0
# 2 1
# 3 11
# 4 36
# 5 49
# 6 35
# 7 17

# %%
happy[happy['Ladder score']<3]
# Out:
#     Country name Regional indicator  Ladder score  \
# 148  Afghanistan         South Asia         2.523
#
#      Standard error of ladder score  upperwhisker  lowerwhisker  \
# 148                           0.038         2.596         2.449
#
#      Logged GDP per capita  Social support  Healthy life expectancy  \
# 148                  7.695           0.463                   52.493
#
#      Freedom to make life choices  Generosity  Perceptions of corruption  \
# 148                         0.382      -0.102                      0.924
#
#      Ladder score in Dystopia  Explained by: Log GDP per capita  \
# 148                      2.43                              0.37
#
#      Explained by: Social support  Explained by: Healthy life expectancy  \
# 148                           0.0                                  0.126
#
#      Explained by: Freedom to make life choices  Explained by: Generosity  \
# 148                                         0.0                     0.122
#
# ...

# %%
happy.sort_values('Country name')
# Out:
#     Country name                  Regional indicator  Ladder score  \
# 148  Afghanistan                          South Asia         2.523
# 92       Albania          Central and Eastern Europe         5.117
# 108      Algeria        Middle East and North Africa         4.887
# 56     Argentina         Latin America and Caribbean         5.929
# 85       Armenia  Commonwealth of Independent States         5.283
# ..           ...                                 ...           ...
# 106    Venezuela         Latin America and Caribbean         4.892
# 78       Vietnam                      Southeast Asia         5.411
# 140        Yemen        Middle East and North Africa         3.658
# 136       Zambia                  Sub-Saharan Africa         4.073
# 147     Zimbabwe                  Sub-Saharan Africa         3.145
#
#      Standard error of ladder score  upperwhisker  lowerwhisker  \
# 148                           0.038         2.596         2.449
# ...

# %%
(happy['Country name'].str[0]).value_counts()
# Out:
# M    15
# S    14
# C    13
# B    12
# N    10
# I     9
# T     8
# P     8
# L     8
# A     8
# G     8
# U     7
# K     5
# E     5
# H     4
# J     3
# R     3
# Z     2
# V     2
# D     2
# F     2
# Y     1
# Name: Country name, dtype: int64

# %%
data
# Out:
#    국어  영어  지역
# 0  99  88  서울
# 1  76  89  부산
# 2  86  95  원주
# 3  63  76  서울

# %%
data2 = data.sort_values(['지역', '영어'])
data2
# Out:
#    국어  영어  지역
# 1  76  89  부산
# 3  63  76  서울
# 0  99  88  서울
# 2  86  95  원주

# %%
data2.reset_index(drop=True)
# Out:
#    국어  영어  지역
# 0  76  89  부산
# 1  63  76  서울
# 2  99  88  서울
# 3  86  95  원주

# %%
data2['total'] = data2.국어+data2.영어
data2.sort_values('total')
# Out:
#    국어  영어  지역  total
# 3  63  76  서울    139
# 1  76  89  부산    165
# 2  86  95  원주    181
# 0  99  88  서울    187

# %%
from io import StringIO

buffer = '''이름,나이,지역,생일
"홍길동",22,,1990/1/1
장길산,"33","원주","1981/2/2"
둘리,"",강릉,2005/3/3'''

data = pd.read_csv(StringIO(buffer), parse_dates=[3])
data
# Out:
#     이름    나이   지역         생일
# 0  홍길동  22.0  NaN 1990-01-01
# 1  장길산  33.0   원주 1981-02-02
# 2   둘리   NaN   강릉 2005-03-03

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3 entries, 0 to 2
# Data columns (total 4 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   이름      3 non-null      object
#  1   나이      2 non-null      float64
#  2   지역      2 non-null      object
#  3   생일      3 non-null      datetime64[ns]
# dtypes: datetime64[ns](1), float64(1), object(2)
# memory usage: 224.0+ bytes

# %%
data.dropna() # 샘플을 지워버림
# Out:
#     이름    나이  지역         생일
# 1  장길산  33.0  원주 1981-02-02

# %%
data.fillna({'나이':0, '지역':'서울'}) # 기본값으로 설정
# Out:
#     이름    나이  지역         생일
# 0  홍길동  22.0  서울 1990-01-01
# 1  장길산  33.0  원주 1981-02-02
# 2   둘리   0.0  강릉 2005-03-03

# %%
data.fillna(method='ffill')
# Out:
#     이름    나이   지역         생일
# 0  홍길동  22.0  NaN 1990-01-01
# 1  장길산  33.0   원주 1981-02-02
# 2   둘리  33.0   강릉 2005-03-03

# %%
data.fillna(method='bfill')
# Out:
#     이름    나이  지역         생일
# 0  홍길동  22.0  원주 1990-01-01
# 1  장길산  33.0  원주 1981-02-02
# 2   둘리   NaN  강릉 2005-03-03

# %%
data.mean()
# Out:
# <ipython-input-100-abc01cf6c622>:1: FutureWarning: DataFrame.mean and DataFrame.median with numeric_only=None will include datetime64 and datetime64tz columns in a future version.
#   data.mean()
# 나이    27.5
# dtype: float64

# %%
data.fillna(data.mean())
# Out:
# <ipython-input-99-f4696802a847>:1: FutureWarning: DataFrame.mean and DataFrame.median with numeric_only=None will include datetime64 and datetime64tz columns in a future version.
#   data.fillna(data.mean())
#     이름    나이   지역         생일
# 0  홍길동  22.0  NaN 1990-01-01
# 1  장길산  33.0   원주 1981-02-02
# 2   둘리  27.5   강릉 2005-03-03

# %%
data
# Out:
#     이름    나이   지역         생일
# 0  홍길동  22.0  NaN 1990-01-01
# 1  장길산  33.0   원주 1981-02-02
# 2   둘리   NaN   강릉 2005-03-03

# %%
data.isnull()
# Out:
#       이름     나이     지역     생일
# 0  False  False   True  False
# 1  False  False  False  False
# 2  False   True  False  False

# %%
data.notnull()
# Out:
#      이름     나이     지역    생일
# 0  True   True  False  True
# 1  True   True   True  True
# 2  True  False   True  True

# %%
data.isnull().any(axis=1)
# Out:
# 0     True
# 1    False
# 2     True
# dtype: bool

# %%
data[data.isnull().any(axis=1)]
# Out:
#     이름    나이   지역         생일
# 0  홍길동  22.0  NaN 1990-01-01
# 2   둘리   NaN   강릉 2005-03-03

# %%
data[data.notnull().all(1)]
# Out:
#     이름    나이  지역         생일
# 1  장길산  33.0  원주 1981-02-02

# %%
data
# Out:
#     이름    나이   지역         생일
# 0  홍길동  22.0  NaN 1990-01-01
# 1  장길산  33.0   원주 1981-02-02
# 2   둘리   NaN   강릉 2005-03-03

# %%
data = pd.DataFrame([[99,88,'서울'], [76,89,'부산'],
                    [86,95,'원주'], [63,76,'서울']],
                   columns=['국어','영어','지역'])
data
# Out:
#    국어  영어  지역
# 0  99  88  서울
# 1  76  89  부산
# 2  86  95  원주
# 3  63  76  서울

# %%
data.국어.map(lambda n: (n - data.국어.mean())/data.국어.std())
# Out:
# 0    1.180064
# 1   -0.327795
# 2    0.327795
# 3   -1.180064
# Name: 국어, dtype: float64

# %%
data[['국어','영어']].apply(lambda col: col.max()-col.min())
# Out:
# 국어    36
# 영어    19
# dtype: int64

# %%
w = [0.1, 0.2, 0.3, 0.4]
data[['국어','영어']].apply(lambda col: col*w)
# Out:
#      국어    영어
# 0   9.9   8.8
# 1  15.2  17.8
# 2  25.8  28.5
# 3  25.2  30.4

# %%
w = [0.1, 0.2, 0.3, 0.4]
data[['국어','영어']].apply(lambda col: (col*w).sum()) # 칼럼별 적용
# Out:
# 국어    76.1
# 영어    85.5
# dtype: float64

# %%
data[['국어','영어']].applymap(lambda x: x*2) # 항목 하나하나 적용
# Out:
#     국어   영어
# 0  198  176
# 1  152  178
# 2  172  190
# 3  126  152

# %%
data = pd.DataFrame([[1,2],[3,4]], columns=['국어','영어'],
                   index=['홍길동','장길산'])
data
# Out:
#      국어  영어
# 홍길동   1   2
# 장길산   3   4

# %%
data = pd.DataFrame([['홍길동',99,'1999/1/1'],
                     ['장길산',88,'1987/3/1'],
                     ['둘리',51,'2005/5/5']],
                   columns=['이름','성적','생일'])
data
# Out:
#     이름  성적        생일
# 0  홍길동  99  1999/1/1
# 1  장길산  88  1987/3/1
# 2   둘리  51  2005/5/5

# %%
data2 = data.set_index('이름')
data2
# Out:
#      성적        생일
# 이름
# 홍길동  99  1999/1/1
# 장길산  88  1987/3/1
# 둘리   51  2005/5/5

# %%
data2.index
# Out:
# Index(['홍길동', '장길산', '둘리'], dtype='object', name='이름')

# %%
happy
# Out:
#     Country name  Regional indicator  Ladder score  \
# 0        Finland      Western Europe         7.842
# 1        Denmark      Western Europe         7.620
# 2    Switzerland      Western Europe         7.571
# 3        Iceland      Western Europe         7.554
# 4    Netherlands      Western Europe         7.464
# ..           ...                 ...           ...
# 144      Lesotho  Sub-Saharan Africa         3.512
# 145     Botswana  Sub-Saharan Africa         3.467
# 146       Rwanda  Sub-Saharan Africa         3.415
# 147     Zimbabwe  Sub-Saharan Africa         3.145
# 148  Afghanistan          South Asia         2.523
#
#      Standard error of ladder score  upperwhisker  lowerwhisker  \
# 0                             0.032         7.904         7.780
# 1                             0.035         7.687         7.552
# 2                             0.036         7.643         7.500
# 3                             0.059         7.670         7.438
# ...

# %%
happy.set_index('Country name')
# Out:
#               Regional indicator  Ladder score  \
# Country name
# Finland           Western Europe         7.842
# Denmark           Western Europe         7.620
# Switzerland       Western Europe         7.571
# Iceland           Western Europe         7.554
# Netherlands       Western Europe         7.464
# ...                          ...           ...
# Lesotho       Sub-Saharan Africa         3.512
# Botswana      Sub-Saharan Africa         3.467
# Rwanda        Sub-Saharan Africa         3.415
# Zimbabwe      Sub-Saharan Africa         3.145
# Afghanistan           South Asia         2.523
#
#               Standard error of ladder score  upperwhisker  lowerwhisker  \
# Country name
# Finland                                0.032         7.904         7.780
# Denmark                                0.035         7.687         7.552
# Switzerland                            0.036         7.643         7.500
# ...

# %%
data2
# Out:
#      성적        생일
# 이름
# 홍길동  99  1999/1/1
# 장길산  88  1987/3/1
# 둘리   51  2005/5/5

# %%
data2.reset_index()
# Out:
#     이름  성적        생일
# 0  홍길동  99  1999/1/1
# 1  장길산  88  1987/3/1
# 2   둘리  51  2005/5/5

# %%
data2.reset_index(drop=True)
# Out:
#    성적        생일
# 0  99  1999/1/1
# 1  88  1987/3/1
# 2  51  2005/5/5

# %%
data
# Out:
#     이름  성적        생일
# 0  홍길동  99  1999/1/1
# 1  장길산  88  1987/3/1
# 2   둘리  51  2005/5/5

# %%
data4 = pd.DataFrame([['둘리',5,6], ['홍길동',1,2], ['장길산',3,4]],
            columns=['name', '국어', '영어'])
data4
# Out:
#   name  국어  영어
# 0   둘리   5   6
# 1  홍길동   1   2
# 2  장길산   3   4

# %%
data.merge(data4, left_on='이름', right_on='name')
# Out:
#     이름  성적        생일 name  국어  영어
# 0  홍길동  99  1999/1/1  홍길동   1   2
# 1  장길산  88  1987/3/1  장길산   3   4
# 2   둘리  51  2005/5/5   둘리   5   6

# %%
data.merge(data4, left_index=True, right_index=True)
# Out:
#     이름  성적        생일 name  국어  영어
# 0  홍길동  99  1999/1/1   둘리   5   6
# 1  장길산  88  1987/3/1  홍길동   1   2
# 2   둘리  51  2005/5/5  장길산   3   4

# %%
help(data.merge)
# Out:
# Help on method merge in module pandas.core.frame:
#
# merge(right, how='inner', on=None, left_on=None, right_on=None, left_index=False, right_index=False, sort=False, suffixes=('_x', '_y'), copy=True, indicator=False, validate=None) -> 'DataFrame' method of pandas.core.frame.DataFrame instance
#     Merge DataFrame or named Series objects with a database-style join.
#
#     The join is done on columns or indexes. If joining columns on
#     columns, the DataFrame indexes *will be ignored*. Otherwise if joining indexes
#     on indexes or indexes on a column or columns, the index will be passed on.
#
#     Parameters
#     ----------
#     right : DataFrame or named Series
#         Object to merge with.
#     how : {'left', 'right', 'outer', 'inner'}, default 'inner'
#         Type of merge to be performed.
#
#         * left: use only keys from left frame, similar to a SQL left outer join;
#           preserve key order.
# ...

# %%
np.exp(10.267)
# Out:
# 28767.45521773624

# %%
np.exp(10.42)
# Out:
# 33523.43414584466

# %%
happy.groupby('Regional indicator')['Ladder score'].mean()
# Out:
# Regional indicator
# Central and Eastern Europe            5.984765
# Commonwealth of Independent States    5.467000
# East Asia                             5.810333
# Latin America and Caribbean           5.908050
# Middle East and North Africa          5.219765
# North America and ANZ                 7.128500
# South Asia                            4.441857
# Southeast Asia                        5.407556
# Sub-Saharan Africa                    4.494472
# Western Europe                        6.914905
# Name: Ladder score, dtype: float64

# %%
happy.groupby('Regional indicator').mean()['Ladder score']
# Out:
# Regional indicator
# Central and Eastern Europe            5.984765
# Commonwealth of Independent States    5.467000
# East Asia                             5.810333
# Latin America and Caribbean           5.908050
# Middle East and North Africa          5.219765
# North America and ANZ                 7.128500
# South Asia                            4.441857
# Southeast Asia                        5.407556
# Sub-Saharan Africa                    4.494472
# Western Europe                        6.914905
# Name: Ladder score, dtype: float64

# %%
happy.groupby('Regional indicator').mean()
# Out:
#                                     Ladder score  \
# Regional indicator
# Central and Eastern Europe              5.984765
# Commonwealth of Independent States      5.467000
# East Asia                               5.810333
# Latin America and Caribbean             5.908050
# Middle East and North Africa            5.219765
# North America and ANZ                   7.128500
# South Asia                              4.441857
# Southeast Asia                          5.407556
# Sub-Saharan Africa                      4.494472
# Western Europe                          6.914905
#
#                                     Standard error of ladder score  \
# Regional indicator
# Central and Eastern Europe                                0.048471
# Commonwealth of Independent States                        0.046750
# East Asia                                                 0.040000
# Latin America and Caribbean                               0.073900
# ...

# %%
happy.groupby(np.floor(happy['Ladder score']))['Logged GDP per capita'].mean()
# Out:
# Ladder score
# 2.0     7.695000
# 3.0     7.821818
# 4.0     8.616694
# 5.0     9.344980
# 6.0    10.253114
# 7.0    10.864706
# Name: Logged GDP per capita, dtype: float64
