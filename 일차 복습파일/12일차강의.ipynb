# %% [markdown]
# ## 파이썬 데이터분석
# # PANDAS

# %% [markdown]
# ### 연습문제
# - 'world_happiness_report_2021.csv' 를 DataFrame 으로 불러오시오.
# - 칼럼명을 리스트로 변환하시오.
# - 행의 갯수와 열의 갯수를 구하시오.
# - 나라이름을 뽑으시오.
# - 나라이름과 행복지수(Ladder acore)를 뽑으시오.
# - 'Ladder score' 와 'Logged GDP per capita' 를 뽑아 넘파이 어레이로 변환하시오.
# - 한국의 행복지수 값을 뽑으시오.
# - 처음 다섯 행을 뽑으시오.
# - 마지막 다섯 행을 뽑으시오.
# - 처음 다섯행과 마지막 다섯행을 한번에 뽑는 방법을 생각해 보시오.
# - 'Reginal indicator' 를 코드화 시키시오. (set 또는 numpy unique() 함수 사용)
# - 'Logged GDP per capita' 값에 지수함수를 적용한 값을 'gdp' 라는 새로운 칼럼으로 추가하시오. (np.exp() 함수 적용)

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
data = pd.read_csv('world_happiness_report_2021.csv')
data
# Out:
#     Country name  Regional indicator  Ladder score  \
# 0        Finland      Western Europe         7.842
# 1        Denmark      Western Europe         7.620
# 2    Switzerland      Western Europe         7.571
# 3        Iceland      Western Europe         7.554
# 4    Netherlands      Western Europe         7.464
# ..           ...                 ...           ...
# 144      Lesotho  Sub-Saharan Africa         3.512
# 145     Botswana  Sub-Saharan Africa         3.467
# 146       Rwanda  Sub-Saharan Africa         3.415
# 147     Zimbabwe  Sub-Saharan Africa         3.145
# 148  Afghanistan          South Asia         2.523
#
#      Standard error of ladder score  upperwhisker  lowerwhisker  \
# 0                             0.032         7.904         7.780
# 1                             0.035         7.687         7.552
# 2                             0.036         7.643         7.500
# 3                             0.059         7.670         7.438
# 4                             0.027         7.518         7.410
# ..                              ...           ...           ...
# 144                           0.120         3.748         3.276
# 145                           0.074         3.611         3.322
# 146                           0.068         3.548         3.282
# 147                           0.058         3.259         3.030
# 148                           0.038         2.596         2.449
#
#      Logged GDP per capita  Social support  Healthy life expectancy  \
# 0                   10.775           0.954                   72.000
# 1                   10.933           0.954                   72.700
# 2                   11.117           0.942                   74.400
# 3                   10.878           0.983                   73.000
# 4                   10.932           0.942                   72.400
# ..                     ...             ...                      ...
# 144                  7.926           0.787                   48.700
# 145                  9.782           0.784                   59.269
# 146                  7.676           0.552                   61.400
# 147                  7.943           0.750                   56.201
# 148                  7.695           0.463                   52.493
#
#      Freedom to make life choices  Generosity  Perceptions of corruption  \
# 0                           0.949      -0.098                      0.186
# 1                           0.946       0.030                      0.179
# 2                           0.919       0.025                      0.292
# 3                           0.955       0.160                      0.673
# 4                           0.913       0.175                      0.338
# ..                            ...         ...                        ...
# 144                         0.715      -0.131                      0.915
# 145                         0.824      -0.246                      0.801
# 146                         0.897       0.061                      0.167
# 147                         0.677      -0.047                      0.821
# 148                         0.382      -0.102                      0.924
#
#      Ladder score in Dystopia  Explained by: Log GDP per capita  \
# 0                        2.43                             1.446
# 1                        2.43                             1.502
# 2                        2.43                             1.566
# 3                        2.43                             1.482
# 4                        2.43                             1.501
# ..                        ...                               ...
# 144                      2.43                             0.451
# 145                      2.43                             1.099
# 146                      2.43                             0.364
# 147                      2.43                             0.457
# 148                      2.43                             0.370
#
#      Explained by: Social support  Explained by: Healthy life expectancy  \
# 0                           1.106                                  0.741
# 1                           1.108                                  0.763
# 2                           1.079                                  0.816
# 3                           1.172                                  0.772
# 4                           1.079                                  0.753
# ..                            ...                                    ...
# 144                         0.731                                  0.007
# 145                         0.724                                  0.340
# 146                         0.202                                  0.407
# 147                         0.649                                  0.243
# 148                         0.000                                  0.126
#
#      Explained by: Freedom to make life choices  Explained by: Generosity  \
# 0                                         0.691                     0.124
# 1                                         0.686                     0.208
# 2                                         0.653                     0.204
# 3                                         0.698                     0.293
# 4                                         0.647                     0.302
# ..                                          ...                       ...
# 144                                       0.405                     0.103
# 145                                       0.539                     0.027
# 146                                       0.627                     0.227
# 147                                       0.359                     0.157
# 148                                       0.000                     0.122
#
#      Explained by: Perceptions of corruption  Dystopia + residual
# 0                                      0.481                3.253
# 1                                      0.485                2.868
# 2                                      0.413                2.839
# 3                                      0.170                2.967
# 4                                      0.384                2.798
# ..                                       ...                  ...
# 144                                    0.015                1.800
# 145                                    0.088                0.648
# 146                                    0.493                1.095
# 147                                    0.075                1.205
# 148                                    0.010                1.895
#
# [149 rows x 20 columns]

# %%
features = list(data.columns)
features
# Out:
# ['Country name',
#  'Regional indicator',
#  'Ladder score',
#  'Standard error of ladder score',
#  'upperwhisker',
#  'lowerwhisker',
#  'Logged GDP per capita',
#  'Social support',
#  'Healthy life expectancy',
#  'Freedom to make life choices',
#  'Generosity',
#  'Perceptions of corruption',
#  'Ladder score in Dystopia',
#  'Explained by: Log GDP per capita',
#  'Explained by: Social support',
#  'Explained by: Healthy life expectancy',
#  'Explained by: Freedom to make life choices',
#  'Explained by: Generosity',
#  'Explained by: Perceptions of corruption',
#  'Dystopia + residual']

# %%
data.columns.to_list()
# Out:
# ['Country name',
#  'Regional indicator',
#  'Ladder score',
#  'Standard error of ladder score',
#  'upperwhisker',
#  'lowerwhisker',
#  'Logged GDP per capita',
#  'Social support',
#  'Healthy life expectancy',
#  'Freedom to make life choices',
#  'Generosity',
#  'Perceptions of corruption',
#  'Ladder score in Dystopia',
#  'Explained by: Log GDP per capita',
#  'Explained by: Social support',
#  'Explained by: Healthy life expectancy',
#  'Explained by: Freedom to make life choices',
#  'Explained by: Generosity',
#  'Explained by: Perceptions of corruption',
#  'Dystopia + residual']

# %%
dict(enumerate(features))
# Out:
# {0: 'Country name',
#  1: 'Regional indicator',
#  2: 'Ladder score',
#  3: 'Standard error of ladder score',
#  4: 'upperwhisker',
#  5: 'lowerwhisker',
#  6: 'Logged GDP per capita',
#  7: 'Social support',
#  8: 'Healthy life expectancy',
#  9: 'Freedom to make life choices',
#  10: 'Generosity',
#  11: 'Perceptions of corruption',
#  12: 'Ladder score in Dystopia',
#  13: 'Explained by: Log GDP per capita',
#  14: 'Explained by: Social support',
#  15: 'Explained by: Healthy life expectancy',
#  16: 'Explained by: Freedom to make life choices',
#  17: 'Explained by: Generosity',
#  18: 'Explained by: Perceptions of corruption',
#  19: 'Dystopia + residual'}

# %%
{v:i for i,v in enumerate(features)}
# Out:
# {'Country name': 0,
#  'Regional indicator': 1,
#  'Ladder score': 2,
#  'Standard error of ladder score': 3,
#  'upperwhisker': 4,
#  'lowerwhisker': 5,
#  'Logged GDP per capita': 6,
#  'Social support': 7,
#  'Healthy life expectancy': 8,
#  'Freedom to make life choices': 9,
#  'Generosity': 10,
#  'Perceptions of corruption': 11,
#  'Ladder score in Dystopia': 12,
#  'Explained by: Log GDP per capita': 13,
#  'Explained by: Social support': 14,
#  'Explained by: Healthy life expectancy': 15,
#  'Explained by: Freedom to make life choices': 16,
#  'Explained by: Generosity': 17,
#  'Explained by: Perceptions of corruption': 18,
#  'Dystopia + residual': 19}

# %%
data.shape
# Out:
# (149, 20)

# %%
len(data)
# Out:
# 149

# %%
len(data.columns)
# Out:
# 20

# %%
data['Country name'] # pd.Series
# Out:
# 0          Finland
# 1          Denmark
# 2      Switzerland
# 3          Iceland
# 4      Netherlands
#           ...
# 144        Lesotho
# 145       Botswana
# 146         Rwanda
# 147       Zimbabwe
# 148    Afghanistan
# Name: Country name, Length: 149, dtype: object

# %%
country_code = dict(data['Country name'])
country_code
# Out:
# {0: 'Finland',
#  1: 'Denmark',
#  2: 'Switzerland',
#  3: 'Iceland',
#  4: 'Netherlands',
#  5: 'Norway',
#  6: 'Sweden',
#  7: 'Luxembourg',
#  8: 'New Zealand',
#  9: 'Austria',
#  10: 'Australia',
#  11: 'Israel',
#  12: 'Germany',
#  13: 'Canada',
#  14: 'Ireland',
#  15: 'Costa Rica',
#  16: 'United Kingdom',
#  17: 'Czech Republic',
#  18: 'United States',
#  19: 'Belgium',
#  20: 'France',
#  21: 'Bahrain',
#  22: 'Malta',
#  23: 'Taiwan Province of China',
#  24: 'United Arab Emirates',
#  25: 'Saudi Arabia',
#  26: 'Spain',
#  27: 'Italy',
#  28: 'Slovenia',
#  29: 'Guatemala',
#  30: 'Uruguay',
#  31: 'Singapore',
#  32: 'Kosovo',
#  33: 'Slovakia',
#  34: 'Brazil',
#  35: 'Mexico',
#  36: 'Jamaica',
#  37: 'Lithuania',
#  38: 'Cyprus',
#  39: 'Estonia',
#  40: 'Panama',
#  41: 'Uzbekistan',
#  42: 'Chile',
#  43: 'Poland',
#  44: 'Kazakhstan',
#  45: 'Romania',
#  46: 'Kuwait',
#  47: 'Serbia',
#  48: 'El Salvador',
#  49: 'Mauritius',
#  50: 'Latvia',
#  51: 'Colombia',
#  52: 'Hungary',
#  53: 'Thailand',
#  54: 'Nicaragua',
#  55: 'Japan',
#  56: 'Argentina',
#  57: 'Portugal',
#  58: 'Honduras',
#  59: 'Croatia',
#  60: 'Philippines',
#  61: 'South Korea',
#  62: 'Peru',
#  63: 'Bosnia and Herzegovina',
#  64: 'Moldova',
#  65: 'Ecuador',
#  66: 'Kyrgyzstan',
#  67: 'Greece',
#  68: 'Bolivia',
#  69: 'Mongolia',
#  70: 'Paraguay',
#  71: 'Montenegro',
#  72: 'Dominican Republic',
#  73: 'North Cyprus',
#  74: 'Belarus',
#  75: 'Russia',
#  76: 'Hong Kong S.A.R. of China',
#  77: 'Tajikistan',
#  78: 'Vietnam',
#  79: 'Libya',
#  80: 'Malaysia',
#  81: 'Indonesia',
#  82: 'Congo (Brazzaville)',
#  83: 'China',
#  84: 'Ivory Coast',
#  85: 'Armenia',
#  86: 'Nepal',
#  87: 'Bulgaria',
#  88: 'Maldives',
#  89: 'Azerbaijan',
#  90: 'Cameroon',
#  91: 'Senegal',
#  92: 'Albania',
#  93: 'North Macedonia',
#  94: 'Ghana',
#  95: 'Niger',
#  96: 'Turkmenistan',
#  97: 'Gambia',
#  98: 'Benin',
#  99: 'Laos',
#  100: 'Bangladesh',
#  101: 'Guinea',
#  102: 'South Africa',
#  103: 'Turkey',
#  104: 'Pakistan',
#  105: 'Morocco',
#  106: 'Venezuela',
#  107: 'Georgia',
#  108: 'Algeria',
#  109: 'Ukraine',
#  110: 'Iraq',
#  111: 'Gabon',
#  112: 'Burkina Faso',
#  113: 'Cambodia',
#  114: 'Mozambique',
#  115: 'Nigeria',
#  116: 'Mali',
#  117: 'Iran',
#  118: 'Uganda',
#  119: 'Liberia',
#  120: 'Kenya',
#  121: 'Tunisia',
#  122: 'Lebanon',
#  123: 'Namibia',
#  124: 'Palestinian Territories',
#  125: 'Myanmar',
#  126: 'Jordan',
#  127: 'Chad',
#  128: 'Sri Lanka',
#  129: 'Swaziland',
#  130: 'Comoros',
#  131: 'Egypt',
#  132: 'Ethiopia',
#  133: 'Mauritania',
#  134: 'Madagascar',
#  135: 'Togo',
#  136: 'Zambia',
#  137: 'Sierra Leone',
#  138: 'India',
#  139: 'Burundi',
#  140: 'Yemen',
#  141: 'Tanzania',
#  142: 'Haiti',
#  143: 'Malawi',
#  144: 'Lesotho',
#  145: 'Botswana',
#  146: 'Rwanda',
#  147: 'Zimbabwe',
#  148: 'Afghanistan'}

# %%
{v:k for k,v in country_code.items()}
# Out:
# {'Finland': 0,
#  'Denmark': 1,
#  'Switzerland': 2,
#  'Iceland': 3,
#  'Netherlands': 4,
#  'Norway': 5,
#  'Sweden': 6,
#  'Luxembourg': 7,
#  'New Zealand': 8,
#  'Austria': 9,
#  'Australia': 10,
#  'Israel': 11,
#  'Germany': 12,
#  'Canada': 13,
#  'Ireland': 14,
#  'Costa Rica': 15,
#  'United Kingdom': 16,
#  'Czech Republic': 17,
#  'United States': 18,
#  'Belgium': 19,
#  'France': 20,
#  'Bahrain': 21,
#  'Malta': 22,
#  'Taiwan Province of China': 23,
#  'United Arab Emirates': 24,
#  'Saudi Arabia': 25,
#  'Spain': 26,
#  'Italy': 27,
#  'Slovenia': 28,
#  'Guatemala': 29,
#  'Uruguay': 30,
#  'Singapore': 31,
#  'Kosovo': 32,
#  'Slovakia': 33,
#  'Brazil': 34,
#  'Mexico': 35,
#  'Jamaica': 36,
#  'Lithuania': 37,
#  'Cyprus': 38,
#  'Estonia': 39,
#  'Panama': 40,
#  'Uzbekistan': 41,
#  'Chile': 42,
#  'Poland': 43,
#  'Kazakhstan': 44,
#  'Romania': 45,
#  'Kuwait': 46,
#  'Serbia': 47,
#  'El Salvador': 48,
#  'Mauritius': 49,
#  'Latvia': 50,
#  'Colombia': 51,
#  'Hungary': 52,
#  'Thailand': 53,
#  'Nicaragua': 54,
#  'Japan': 55,
#  'Argentina': 56,
#  'Portugal': 57,
#  'Honduras': 58,
#  'Croatia': 59,
#  'Philippines': 60,
#  'South Korea': 61,
#  'Peru': 62,
#  'Bosnia and Herzegovina': 63,
#  'Moldova': 64,
#  'Ecuador': 65,
#  'Kyrgyzstan': 66,
#  'Greece': 67,
#  'Bolivia': 68,
#  'Mongolia': 69,
#  'Paraguay': 70,
#  'Montenegro': 71,
#  'Dominican Republic': 72,
#  'North Cyprus': 73,
#  'Belarus': 74,
#  'Russia': 75,
#  'Hong Kong S.A.R. of China': 76,
#  'Tajikistan': 77,
#  'Vietnam': 78,
#  'Libya': 79,
#  'Malaysia': 80,
#  'Indonesia': 81,
#  'Congo (Brazzaville)': 82,
#  'China': 83,
#  'Ivory Coast': 84,
#  'Armenia': 85,
#  'Nepal': 86,
#  'Bulgaria': 87,
#  'Maldives': 88,
#  'Azerbaijan': 89,
#  'Cameroon': 90,
#  'Senegal': 91,
#  'Albania': 92,
#  'North Macedonia': 93,
#  'Ghana': 94,
#  'Niger': 95,
#  'Turkmenistan': 96,
#  'Gambia': 97,
#  'Benin': 98,
#  'Laos': 99,
#  'Bangladesh': 100,
#  'Guinea': 101,
#  'South Africa': 102,
#  'Turkey': 103,
#  'Pakistan': 104,
#  'Morocco': 105,
#  'Venezuela': 106,
#  'Georgia': 107,
#  'Algeria': 108,
#  'Ukraine': 109,
#  'Iraq': 110,
#  'Gabon': 111,
#  'Burkina Faso': 112,
#  'Cambodia': 113,
#  'Mozambique': 114,
#  'Nigeria': 115,
#  'Mali': 116,
#  'Iran': 117,
#  'Uganda': 118,
#  'Liberia': 119,
#  'Kenya': 120,
#  'Tunisia': 121,
#  'Lebanon': 122,
#  'Namibia': 123,
#  'Palestinian Territories': 124,
#  'Myanmar': 125,
#  'Jordan': 126,
#  'Chad': 127,
#  'Sri Lanka': 128,
#  'Swaziland': 129,
#  'Comoros': 130,
#  'Egypt': 131,
#  'Ethiopia': 132,
#  'Mauritania': 133,
#  'Madagascar': 134,
#  'Togo': 135,
#  'Zambia': 136,
#  'Sierra Leone': 137,
#  'India': 138,
#  'Burundi': 139,
#  'Yemen': 140,
#  'Tanzania': 141,
#  'Haiti': 142,
#  'Malawi': 143,
#  'Lesotho': 144,
#  'Botswana': 145,
#  'Rwanda': 146,
#  'Zimbabwe': 147,
#  'Afghanistan': 148}

# %%
data[ ['Country name', 'Ladder score'] ]
# Out:
#     Country name  Ladder score
# 0        Finland         7.842
# 1        Denmark         7.620
# 2    Switzerland         7.571
# 3        Iceland         7.554
# 4    Netherlands         7.464
# ..           ...           ...
# 144      Lesotho         3.512
# 145     Botswana         3.467
# 146       Rwanda         3.415
# 147     Zimbabwe         3.145
# 148  Afghanistan         2.523
#
# [149 rows x 2 columns]

# %%
a = data[ ['Ladder score', 'Logged GDP per capita'] ].values
a
# Out:
# array([[ 7.842, 10.775],
#        [ 7.62 , 10.933],
#        [ 7.571, 11.117],
#        [ 7.554, 10.878],
#        [ 7.464, 10.932],
#        [ 7.392, 11.053],
#        [ 7.363, 10.867],
#        [ 7.324, 11.647],
#        [ 7.277, 10.643],
#        [ 7.268, 10.906],
#        [ 7.183, 10.796],
#        [ 7.157, 10.575],
#        [ 7.155, 10.873],
#        [ 7.103, 10.776],
#        [ 7.085, 11.342],
#        [ 7.069,  9.88 ],
#        [ 7.064, 10.707],
#        [ 6.965, 10.556],
#        [ 6.951, 11.023],
#        [ 6.834, 10.823],
#        [ 6.69 , 10.704],
#        [ 6.647, 10.669],
#        [ 6.602, 10.674],
#        [ 6.584, 10.871],
#        [ 6.561, 11.085],
#        [ 6.494, 10.743],
#        [ 6.491, 10.571],
#        [ 6.483, 10.623],
#        [ 6.461, 10.529],
#        [ 6.435,  9.053],
#        [ 6.431,  9.966],
#        [ 6.377, 11.488],
#        [ 6.372,  9.318],
#        [ 6.331, 10.369],
#        [ 6.33 ,  9.577],
#        [ 6.317,  9.859],
#        [ 6.309,  9.186],
#        [ 6.255, 10.499],
#        [ 6.223, 10.576],
#        [ 6.189, 10.481],
#        [ 6.18 , 10.35 ],
#        [ 6.179,  8.836],
#        [ 6.172, 10.071],
#        [ 6.166, 10.382],
#        [ 6.152, 10.155],
#        [ 6.14 , 10.284],
#        [ 6.106, 10.817],
#        [ 6.078,  9.787],
#        [ 6.061,  9.054],
#        [ 6.049, 10.008],
#        [ 6.032, 10.315],
#        [ 6.012,  9.557],
#        [ 5.992, 10.358],
#        [ 5.985,  9.805],
#        [ 5.972,  8.62 ],
#        [ 5.94 , 10.611],
#        [ 5.929,  9.962],
#        [ 5.929, 10.421],
#        [ 5.919,  8.648],
#        [ 5.882, 10.217],
#        [ 5.88 ,  9.076],
#        [ 5.845, 10.651],
#        [ 5.84 ,  9.458],
#        [ 5.813,  9.59 ],
#        [ 5.766,  9.454],
#        [ 5.764,  9.313],
#        [ 5.744,  8.538],
#        [ 5.723, 10.279],
#        [ 5.716,  9.046],
#        [ 5.677,  9.4  ],
#        [ 5.653,  9.448],
#        [ 5.581,  9.94 ],
#        [ 5.545,  9.802],
#        [ 5.536, 10.576],
#        [ 5.534,  9.853],
#        [ 5.477, 10.189],
#        [ 5.477, 11.   ],
#        [ 5.466,  8.091],
#        [ 5.411,  8.973],
#        [ 5.41 ,  9.622],
#        [ 5.384, 10.238],
#        [ 5.345,  9.365],
#        [ 5.342,  8.117],
#        [ 5.339,  9.673],
#        [ 5.306,  8.551],
#        [ 5.283,  9.487],
#        [ 5.269,  8.12 ],
#        [ 5.266, 10.016],
#        [ 5.198,  9.826],
#        [ 5.171,  9.569],
#        [ 5.142,  8.189],
#        [ 5.132,  8.118],
#        [ 5.117,  9.52 ],
#        [ 5.101,  9.693],
#        [ 5.088,  8.58 ],
#        [ 5.074,  7.098],
#        [ 5.066,  9.629],
#        [ 5.051,  7.686],
#        [ 5.045,  8.087],
#        [ 5.03 ,  8.947],
#        [ 5.025,  8.454],
#        [ 4.984,  7.838],
#        [ 4.956,  9.403],
#        [ 4.948, 10.24 ],
#        [ 4.934,  8.458],
#        [ 4.918,  8.903],
#        [ 4.892,  9.073],
#        [ 4.891,  9.585],
#        [ 4.887,  9.342],
#        [ 4.875,  9.436],
#        [ 4.854,  9.24 ],
#        [ 4.852,  9.603],
#        [ 4.834,  7.678],
#        [ 4.83 ,  8.36 ],
#        [ 4.794,  7.158],
#        [ 4.759,  8.533],
#        [ 4.723,  7.744],
#        [ 4.721,  9.584],
#        [ 4.636,  7.677],
#        [ 4.625,  7.288],
#        [ 4.607,  8.361],
#        [ 4.596,  9.266],
#        [ 4.584,  9.626],
#        [ 4.574,  9.161],
#        [ 4.517,  8.485],
#        [ 4.426,  8.541],
#        [ 4.395,  9.182],
#        [ 4.355,  7.364],
#        [ 4.325,  9.47 ],
#        [ 4.308,  9.065],
#        [ 4.289,  8.031],
#        [ 4.283,  9.367],
#        [ 4.275,  7.694],
#        [ 4.227,  8.542],
#        [ 4.208,  7.396],
#        [ 4.107,  7.362],
#        [ 4.073,  8.145],
#        [ 3.849,  7.434],
#        [ 3.819,  8.755],
#        [ 3.775,  6.635],
#        [ 3.658,  7.578],
#        [ 3.623,  7.876],
#        [ 3.615,  7.477],
#        [ 3.6  ,  6.958],
#        [ 3.512,  7.926],
#        [ 3.467,  9.782],
#        [ 3.415,  7.676],
#        [ 3.145,  7.943],
#        [ 2.523,  7.695]])

# %%
plt.scatter(a[:,1], a[:,0])
plt.ylabel('ladder score')
plt.xlabel('logged gdp')
# Out:
# Text(0.5, 0, 'logged gdp')

# %%
data['Country name']
# Out:
# 0          Finland
# 1          Denmark
# 2      Switzerland
# 3          Iceland
# 4      Netherlands
#           ...
# 144        Lesotho
# 145       Botswana
# 146         Rwanda
# 147       Zimbabwe
# 148    Afghanistan
# Name: Country name, Length: 149, dtype: object

# %%
for i in range(149):
    print(i, data['Country name'][i])
# Out:
# 0 Finland
# 1 Denmark
# 2 Switzerland
# 3 Iceland
# 4 Netherlands
# 5 Norway
# 6 Sweden
# 7 Luxembourg
# 8 New Zealand
# 9 Austria
# 10 Australia
# 11 Israel
# 12 Germany
# 13 Canada
# 14 Ireland
# 15 Costa Rica
# 16 United Kingdom
# 17 Czech Republic
# 18 United States
# 19 Belgium
# 20 France
# 21 Bahrain
# 22 Malta
# 23 Taiwan Province of China
# 24 United Arab Emirates
# 25 Saudi Arabia
# 26 Spain
# 27 Italy
# 28 Slovenia
# 29 Guatemala
# 30 Uruguay
# 31 Singapore
# 32 Kosovo
# 33 Slovakia
# 34 Brazil
# 35 Mexico
# 36 Jamaica
# 37 Lithuania
# 38 Cyprus
# 39 Estonia
# 40 Panama
# 41 Uzbekistan
# 42 Chile
# 43 Poland
# 44 Kazakhstan
# 45 Romania
# 46 Kuwait
# 47 Serbia
# 48 El Salvador
# 49 Mauritius
# 50 Latvia
# 51 Colombia
# 52 Hungary
# 53 Thailand
# 54 Nicaragua
# 55 Japan
# 56 Argentina
# 57 Portugal
# 58 Honduras
# 59 Croatia
# 60 Philippines
# 61 South Korea
# 62 Peru
# 63 Bosnia and Herzegovina
# 64 Moldova
# 65 Ecuador
# 66 Kyrgyzstan
# 67 Greece
# 68 Bolivia
# 69 Mongolia
# 70 Paraguay
# 71 Montenegro
# 72 Dominican Republic
# 73 North Cyprus
# 74 Belarus
# 75 Russia
# 76 Hong Kong S.A.R. of China
# 77 Tajikistan
# 78 Vietnam
# 79 Libya
# 80 Malaysia
# 81 Indonesia
# 82 Congo (Brazzaville)
# 83 China
# 84 Ivory Coast
# 85 Armenia
# 86 Nepal
# 87 Bulgaria
# 88 Maldives
# 89 Azerbaijan
# 90 Cameroon
# 91 Senegal
# 92 Albania
# 93 North Macedonia
# 94 Ghana
# 95 Niger
# 96 Turkmenistan
# 97 Gambia
# 98 Benin
# 99 Laos
# 100 Bangladesh
# 101 Guinea
# 102 South Africa
# 103 Turkey
# 104 Pakistan
# 105 Morocco
# 106 Venezuela
# 107 Georgia
# 108 Algeria
# 109 Ukraine
# 110 Iraq
# 111 Gabon
# 112 Burkina Faso
# 113 Cambodia
# 114 Mozambique
# 115 Nigeria
# 116 Mali
# 117 Iran
# 118 Uganda
# 119 Liberia
# 120 Kenya
# 121 Tunisia
# 122 Lebanon
# 123 Namibia
# 124 Palestinian Territories
# 125 Myanmar
# 126 Jordan
# 127 Chad
# 128 Sri Lanka
# 129 Swaziland
# 130 Comoros
# 131 Egypt
# 132 Ethiopia
# 133 Mauritania
# 134 Madagascar
# 135 Togo
# 136 Zambia
# 137 Sierra Leone
# 138 India
# 139 Burundi
# 140 Yemen
# 141 Tanzania
# 142 Haiti
# 143 Malawi
# 144 Lesotho
# 145 Botswana
# 146 Rwanda
# 147 Zimbabwe
# 148 Afghanistan

# %%
for i in range(149):
    if data['Country name'][i].upper().find('KOREA')>0:
        print(i, data['Country name'][i])
# Out:
# 61 South Korea

# %%
data['Ladder score'][61]
# Out:
# 5.845

# %%
data['Ladder score'].mean()
# Out:
# 5.532838926174494

# %%
data.iloc[61,2]
# Out:
# 5.845

# %%
data[:5]
# Out:
#   Country name Regional indicator  Ladder score  \
# 0      Finland     Western Europe         7.842
# 1      Denmark     Western Europe         7.620
# 2  Switzerland     Western Europe         7.571
# 3      Iceland     Western Europe         7.554
# 4  Netherlands     Western Europe         7.464
#
#    Standard error of ladder score  upperwhisker  lowerwhisker  \
# 0                           0.032         7.904         7.780
# 1                           0.035         7.687         7.552
# 2                           0.036         7.643         7.500
# 3                           0.059         7.670         7.438
# 4                           0.027         7.518         7.410
#
#    Logged GDP per capita  Social support  Healthy life expectancy  \
# 0                 10.775           0.954                     72.0
# 1                 10.933           0.954                     72.7
# 2                 11.117           0.942                     74.4
# 3                 10.878           0.983                     73.0
# 4                 10.932           0.942                     72.4
#
#    Freedom to make life choices  Generosity  Perceptions of corruption  \
# 0                         0.949      -0.098                      0.186
# 1                         0.946       0.030                      0.179
# 2                         0.919       0.025                      0.292
# 3                         0.955       0.160                      0.673
# 4                         0.913       0.175                      0.338
#
#    Ladder score in Dystopia  Explained by: Log GDP per capita  \
# 0                      2.43                             1.446
# 1                      2.43                             1.502
# 2                      2.43                             1.566
# 3                      2.43                             1.482
# 4                      2.43                             1.501
#
#    Explained by: Social support  Explained by: Healthy life expectancy  \
# 0                         1.106                                  0.741
# 1                         1.108                                  0.763
# 2                         1.079                                  0.816
# 3                         1.172                                  0.772
# 4                         1.079                                  0.753
#
#    Explained by: Freedom to make life choices  Explained by: Generosity  \
# 0                                       0.691                     0.124
# 1                                       0.686                     0.208
# 2                                       0.653                     0.204
# 3                                       0.698                     0.293
# 4                                       0.647                     0.302
#
#    Explained by: Perceptions of corruption  Dystopia + residual
# 0                                    0.481                3.253
# 1                                    0.485                2.868
# 2                                    0.413                2.839
# 3                                    0.170                2.967
# 4                                    0.384                2.798

# %%
data[-5:]
# Out:
#     Country name  Regional indicator  Ladder score  \
# 144      Lesotho  Sub-Saharan Africa         3.512
# 145     Botswana  Sub-Saharan Africa         3.467
# 146       Rwanda  Sub-Saharan Africa         3.415
# 147     Zimbabwe  Sub-Saharan Africa         3.145
# 148  Afghanistan          South Asia         2.523
#
#      Standard error of ladder score  upperwhisker  lowerwhisker  \
# 144                           0.120         3.748         3.276
# 145                           0.074         3.611         3.322
# 146                           0.068         3.548         3.282
# 147                           0.058         3.259         3.030
# 148                           0.038         2.596         2.449
#
#      Logged GDP per capita  Social support  Healthy life expectancy  \
# 144                  7.926           0.787                   48.700
# 145                  9.782           0.784                   59.269
# 146                  7.676           0.552                   61.400
# 147                  7.943           0.750                   56.201
# 148                  7.695           0.463                   52.493
#
#      Freedom to make life choices  Generosity  Perceptions of corruption  \
# 144                         0.715      -0.131                      0.915
# 145                         0.824      -0.246                      0.801
# 146                         0.897       0.061                      0.167
# 147                         0.677      -0.047                      0.821
# 148                         0.382      -0.102                      0.924
#
#      Ladder score in Dystopia  Explained by: Log GDP per capita  \
# 144                      2.43                             0.451
# 145                      2.43                             1.099
# 146                      2.43                             0.364
# 147                      2.43                             0.457
# 148                      2.43                             0.370
#
#      Explained by: Social support  Explained by: Healthy life expectancy  \
# 144                         0.731                                  0.007
# 145                         0.724                                  0.340
# 146                         0.202                                  0.407
# 147                         0.649                                  0.243
# 148                         0.000                                  0.126
#
#      Explained by: Freedom to make life choices  Explained by: Generosity  \
# 144                                       0.405                     0.103
# 145                                       0.539                     0.027
# 146                                       0.627                     0.227
# 147                                       0.359                     0.157
# 148                                       0.000                     0.122
#
#      Explained by: Perceptions of corruption  Dystopia + residual
# 144                                    0.015                1.800
# 145                                    0.088                0.648
# 146                                    0.493                1.095
# 147                                    0.075                1.205
# 148                                    0.010                1.895

# %%
data.head()
# Out:
#   Country name Regional indicator  Ladder score  \
# 0      Finland     Western Europe         7.842
# 1      Denmark     Western Europe         7.620
# 2  Switzerland     Western Europe         7.571
# 3      Iceland     Western Europe         7.554
# 4  Netherlands     Western Europe         7.464
#
#    Standard error of ladder score  upperwhisker  lowerwhisker  \
# 0                           0.032         7.904         7.780
# 1                           0.035         7.687         7.552
# 2                           0.036         7.643         7.500
# 3                           0.059         7.670         7.438
# 4                           0.027         7.518         7.410
#
#    Logged GDP per capita  Social support  Healthy life expectancy  \
# 0                 10.775           0.954                     72.0
# 1                 10.933           0.954                     72.7
# 2                 11.117           0.942                     74.4
# 3                 10.878           0.983                     73.0
# 4                 10.932           0.942                     72.4
#
#    Freedom to make life choices  Generosity  Perceptions of corruption  \
# 0                         0.949      -0.098                      0.186
# 1                         0.946       0.030                      0.179
# 2                         0.919       0.025                      0.292
# 3                         0.955       0.160                      0.673
# 4                         0.913       0.175                      0.338
#
#    Ladder score in Dystopia  Explained by: Log GDP per capita  \
# 0                      2.43                             1.446
# 1                      2.43                             1.502
# 2                      2.43                             1.566
# 3                      2.43                             1.482
# 4                      2.43                             1.501
#
#    Explained by: Social support  Explained by: Healthy life expectancy  \
# 0                         1.106                                  0.741
# 1                         1.108                                  0.763
# 2                         1.079                                  0.816
# 3                         1.172                                  0.772
# 4                         1.079                                  0.753
#
#    Explained by: Freedom to make life choices  Explained by: Generosity  \
# 0                                       0.691                     0.124
# 1                                       0.686                     0.208
# 2                                       0.653                     0.204
# 3                                       0.698                     0.293
# 4                                       0.647                     0.302
#
#    Explained by: Perceptions of corruption  Dystopia + residual
# 0                                    0.481                3.253
# 1                                    0.485                2.868
# 2                                    0.413                2.839
# 3                                    0.170                2.967
# 4                                    0.384                2.798

# %%
data.tail()
# Out:
#     Country name  Regional indicator  Ladder score  \
# 144      Lesotho  Sub-Saharan Africa         3.512
# 145     Botswana  Sub-Saharan Africa         3.467
# 146       Rwanda  Sub-Saharan Africa         3.415
# 147     Zimbabwe  Sub-Saharan Africa         3.145
# 148  Afghanistan          South Asia         2.523
#
#      Standard error of ladder score  upperwhisker  lowerwhisker  \
# 144                           0.120         3.748         3.276
# 145                           0.074         3.611         3.322
# 146                           0.068         3.548         3.282
# 147                           0.058         3.259         3.030
# 148                           0.038         2.596         2.449
#
#      Logged GDP per capita  Social support  Healthy life expectancy  \
# 144                  7.926           0.787                   48.700
# 145                  9.782           0.784                   59.269
# 146                  7.676           0.552                   61.400
# 147                  7.943           0.750                   56.201
# 148                  7.695           0.463                   52.493
#
#      Freedom to make life choices  Generosity  Perceptions of corruption  \
# 144                         0.715      -0.131                      0.915
# 145                         0.824      -0.246                      0.801
# 146                         0.897       0.061                      0.167
# 147                         0.677      -0.047                      0.821
# 148                         0.382      -0.102                      0.924
#
#      Ladder score in Dystopia  Explained by: Log GDP per capita  \
# 144                      2.43                             0.451
# 145                      2.43                             1.099
# 146                      2.43                             0.364
# 147                      2.43                             0.457
# 148                      2.43                             0.370
#
#      Explained by: Social support  Explained by: Healthy life expectancy  \
# 144                         0.731                                  0.007
# 145                         0.724                                  0.340
# 146                         0.202                                  0.407
# 147                         0.649                                  0.243
# 148                         0.000                                  0.126
#
#      Explained by: Freedom to make life choices  Explained by: Generosity  \
# 144                                       0.405                     0.103
# 145                                       0.539                     0.027
# 146                                       0.627                     0.227
# 147                                       0.359                     0.157
# 148                                       0.000                     0.122
#
#      Explained by: Perceptions of corruption  Dystopia + residual
# 144                                    0.015                1.800
# 145                                    0.088                0.648
# 146                                    0.493                1.095
# 147                                    0.075                1.205
# 148                                    0.010                1.895

# %%
data.iloc[list(range(5)) + list(range(-5,0))]
# Out:
#     Country name  Regional indicator  Ladder score  \
# 0        Finland      Western Europe         7.842
# 1        Denmark      Western Europe         7.620
# 2    Switzerland      Western Europe         7.571
# 3        Iceland      Western Europe         7.554
# 4    Netherlands      Western Europe         7.464
# 144      Lesotho  Sub-Saharan Africa         3.512
# 145     Botswana  Sub-Saharan Africa         3.467
# 146       Rwanda  Sub-Saharan Africa         3.415
# 147     Zimbabwe  Sub-Saharan Africa         3.145
# 148  Afghanistan          South Asia         2.523
#
#      Standard error of ladder score  upperwhisker  lowerwhisker  \
# 0                             0.032         7.904         7.780
# 1                             0.035         7.687         7.552
# 2                             0.036         7.643         7.500
# 3                             0.059         7.670         7.438
# 4                             0.027         7.518         7.410
# 144                           0.120         3.748         3.276
# 145                           0.074         3.611         3.322
# 146                           0.068         3.548         3.282
# 147                           0.058         3.259         3.030
# 148                           0.038         2.596         2.449
#
#      Logged GDP per capita  Social support  Healthy life expectancy  \
# 0                   10.775           0.954                   72.000
# 1                   10.933           0.954                   72.700
# 2                   11.117           0.942                   74.400
# 3                   10.878           0.983                   73.000
# 4                   10.932           0.942                   72.400
# 144                  7.926           0.787                   48.700
# 145                  9.782           0.784                   59.269
# 146                  7.676           0.552                   61.400
# 147                  7.943           0.750                   56.201
# 148                  7.695           0.463                   52.493
#
#      Freedom to make life choices  Generosity  Perceptions of corruption  \
# 0                           0.949      -0.098                      0.186
# 1                           0.946       0.030                      0.179
# 2                           0.919       0.025                      0.292
# 3                           0.955       0.160                      0.673
# 4                           0.913       0.175                      0.338
# 144                         0.715      -0.131                      0.915
# 145                         0.824      -0.246                      0.801
# 146                         0.897       0.061                      0.167
# 147                         0.677      -0.047                      0.821
# 148                         0.382      -0.102                      0.924
#
#      Ladder score in Dystopia  Explained by: Log GDP per capita  \
# 0                        2.43                             1.446
# 1                        2.43                             1.502
# 2                        2.43                             1.566
# 3                        2.43                             1.482
# 4                        2.43                             1.501
# 144                      2.43                             0.451
# 145                      2.43                             1.099
# 146                      2.43                             0.364
# 147                      2.43                             0.457
# 148                      2.43                             0.370
#
#      Explained by: Social support  Explained by: Healthy life expectancy  \
# 0                           1.106                                  0.741
# 1                           1.108                                  0.763
# 2                           1.079                                  0.816
# 3                           1.172                                  0.772
# 4                           1.079                                  0.753
# 144                         0.731                                  0.007
# 145                         0.724                                  0.340
# 146                         0.202                                  0.407
# 147                         0.649                                  0.243
# 148                         0.000                                  0.126
#
#      Explained by: Freedom to make life choices  Explained by: Generosity  \
# 0                                         0.691                     0.124
# 1                                         0.686                     0.208
# 2                                         0.653                     0.204
# 3                                         0.698                     0.293
# 4                                         0.647                     0.302
# 144                                       0.405                     0.103
# 145                                       0.539                     0.027
# 146                                       0.627                     0.227
# 147                                       0.359                     0.157
# 148                                       0.000                     0.122
#
#      Explained by: Perceptions of corruption  Dystopia + residual
# 0                                      0.481                3.253
# 1                                      0.485                2.868
# 2                                      0.413                2.839
# 3                                      0.170                2.967
# 4                                      0.384                2.798
# 144                                    0.015                1.800
# 145                                    0.088                0.648
# 146                                    0.493                1.095
# 147                                    0.075                1.205
# 148                                    0.010                1.895

# %%
data['Regional indicator']
# Out:
# 0          Western Europe
# 1          Western Europe
# 2          Western Europe
# 3          Western Europe
# 4          Western Europe
#               ...
# 144    Sub-Saharan Africa
# 145    Sub-Saharan Africa
# 146    Sub-Saharan Africa
# 147    Sub-Saharan Africa
# 148            South Asia
# Name: Regional indicator, Length: 149, dtype: object

# %%
rc = sorted(list(set(data['Regional indicator'])))
rc
# Out:
# ['Central and Eastern Europe',
#  'Commonwealth of Independent States',
#  'East Asia',
#  'Latin America and Caribbean',
#  'Middle East and North Africa',
#  'North America and ANZ',
#  'South Asia',
#  'Southeast Asia',
#  'Sub-Saharan Africa',
#  'Western Europe']

# %%
{v:i for i,v in enumerate(rc)}
# Out:
# {'Central and Eastern Europe': 0,
#  'Commonwealth of Independent States': 1,
#  'East Asia': 2,
#  'Latin America and Caribbean': 3,
#  'Middle East and North Africa': 4,
#  'North America and ANZ': 5,
#  'South Asia': 6,
#  'Southeast Asia': 7,
#  'Sub-Saharan Africa': 8,
#  'Western Europe': 9}

# %%
r = np.log([10,100,1000,10000])
r
# Out:
# array([2.30258509, 4.60517019, 6.90775528, 9.21034037])

# %%
np.exp(r)
# Out:
# array([1.e+01, 1.e+02, 1.e+03, 1.e+04])

# %%
gdp = np.exp(data['Logged GDP per capita'])
gdp
# Out:
# 0      47810.473244
# 1      55994.010016
# 2      67305.686038
# 3      52997.498855
# 4      55938.043994
#            ...
# 144     2768.331303
# 145    17712.041536
# 146     2155.978587
# 147     2815.795236
# 148     2197.333810
# Name: Logged GDP per capita, Length: 149, dtype: float64

# %%
data2 = data.copy()
data2['gdp'] = np.exp(data['Logged GDP per capita'])
data2
# Out:
#     Country name  Regional indicator  Ladder score  \
# 0        Finland      Western Europe         7.842
# 1        Denmark      Western Europe         7.620
# 2    Switzerland      Western Europe         7.571
# 3        Iceland      Western Europe         7.554
# 4    Netherlands      Western Europe         7.464
# ..           ...                 ...           ...
# 144      Lesotho  Sub-Saharan Africa         3.512
# 145     Botswana  Sub-Saharan Africa         3.467
# 146       Rwanda  Sub-Saharan Africa         3.415
# 147     Zimbabwe  Sub-Saharan Africa         3.145
# 148  Afghanistan          South Asia         2.523
#
#      Standard error of ladder score  upperwhisker  lowerwhisker  \
# 0                             0.032         7.904         7.780
# 1                             0.035         7.687         7.552
# 2                             0.036         7.643         7.500
# 3                             0.059         7.670         7.438
# 4                             0.027         7.518         7.410
# ..                              ...           ...           ...
# 144                           0.120         3.748         3.276
# 145                           0.074         3.611         3.322
# 146                           0.068         3.548         3.282
# 147                           0.058         3.259         3.030
# 148                           0.038         2.596         2.449
#
#      Logged GDP per capita  Social support  Healthy life expectancy  \
# 0                   10.775           0.954                   72.000
# 1                   10.933           0.954                   72.700
# 2                   11.117           0.942                   74.400
# 3                   10.878           0.983                   73.000
# 4                   10.932           0.942                   72.400
# ..                     ...             ...                      ...
# 144                  7.926           0.787                   48.700
# 145                  9.782           0.784                   59.269
# 146                  7.676           0.552                   61.400
# 147                  7.943           0.750                   56.201
# 148                  7.695           0.463                   52.493
#
#      Freedom to make life choices  ...  Perceptions of corruption  \
# 0                           0.949  ...                      0.186
# 1                           0.946  ...                      0.179
# 2                           0.919  ...                      0.292
# 3                           0.955  ...                      0.673
# 4                           0.913  ...                      0.338
# ..                            ...  ...                        ...
# 144                         0.715  ...                      0.915
# 145                         0.824  ...                      0.801
# 146                         0.897  ...                      0.167
# 147                         0.677  ...                      0.821
# 148                         0.382  ...                      0.924
#
#      Ladder score in Dystopia  Explained by: Log GDP per capita  \
# 0                        2.43                             1.446
# 1                        2.43                             1.502
# 2                        2.43                             1.566
# 3                        2.43                             1.482
# 4                        2.43                             1.501
# ..                        ...                               ...
# 144                      2.43                             0.451
# 145                      2.43                             1.099
# 146                      2.43                             0.364
# 147                      2.43                             0.457
# 148                      2.43                             0.370
#
#      Explained by: Social support  Explained by: Healthy life expectancy  \
# 0                           1.106                                  0.741
# 1                           1.108                                  0.763
# 2                           1.079                                  0.816
# 3                           1.172                                  0.772
# 4                           1.079                                  0.753
# ..                            ...                                    ...
# 144                         0.731                                  0.007
# 145                         0.724                                  0.340
# 146                         0.202                                  0.407
# 147                         0.649                                  0.243
# 148                         0.000                                  0.126
#
#      Explained by: Freedom to make life choices  Explained by: Generosity  \
# 0                                         0.691                     0.124
# 1                                         0.686                     0.208
# 2                                         0.653                     0.204
# 3                                         0.698                     0.293
# 4                                         0.647                     0.302
# ..                                          ...                       ...
# 144                                       0.405                     0.103
# 145                                       0.539                     0.027
# 146                                       0.627                     0.227
# 147                                       0.359                     0.157
# 148                                       0.000                     0.122
#
#      Explained by: Perceptions of corruption  Dystopia + residual  \
# 0                                      0.481                3.253
# 1                                      0.485                2.868
# 2                                      0.413                2.839
# 3                                      0.170                2.967
# 4                                      0.384                2.798
# ..                                       ...                  ...
# 144                                    0.015                1.800
# 145                                    0.088                0.648
# 146                                    0.493                1.095
# 147                                    0.075                1.205
# 148                                    0.010                1.895
#
#               gdp
# 0    47810.473244
# 1    55994.010016
# 2    67305.686038
# 3    52997.498855
# 4    55938.043994
# ..            ...
# 144   2768.331303
# 145  17712.041536
# 146   2155.978587
# 147   2815.795236
# 148   2197.333810
#
# [149 rows x 21 columns]

# %%
plt.figure(figsize=[12,6])
plt.subplot(1,2,1)
plt.scatter(data2.gdp, data2['Ladder score'])
plt.subplot(1,2,2)
plt.scatter(data2['Logged GDP per capita'], data2['Ladder score'])

# %% [markdown]
# ### Pandas 기초

# %%
data = pd.DataFrame([['홍길동',99,'1999/1/1'],
                     ['장길산',88,'1987/3/1'],
                     ['둘리',51,'2005/5/5']],
                   columns=['이름','성적','생일'])
data
# Out:
#     이름  성적        생일
# 0  홍길동  99  1999/1/1
# 1  장길산  88  1987/3/1
# 2   둘리  51  2005/5/5

# %%
data.이름
# Out:
# 0    홍길동
# 1    장길산
# 2     둘리
# Name: 이름, dtype: object

# %%
data.이름.to_frame()
# Out:
#     이름
# 0  홍길동
# 1  장길산
# 2   둘리

# %%
data[['이름']] # data[['이름','성적']] 과 비교
# Out:
#     이름
# 0  홍길동
# 1  장길산
# 2   둘리

# %%
a = np.array([[1,2],[3,4],[5,6]])
a[[0]] # a[[0,1]] 과 비교
# Out:
# array([[1, 2]])

# %%
data = pd.DataFrame({'국어': [99,76,86,63],
                    '영어': [88,89,95,76],
                    '지역': ['서울','부산','원주','서울']})
data
# Out:
#    국어  영어  지역
# 0  99  88  서울
# 1  76  89  부산
# 2  86  95  원주
# 3  63  76  서울

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4 entries, 0 to 3
# Data columns (total 3 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   국어      4 non-null      int64
#  1   영어      4 non-null      int64
#  2   지역      4 non-null      object
# dtypes: int64(2), object(1)
# memory usage: 224.0+ bytes

# %%
code = np.sort(data.지역.unique())
code
# Out:
# array(['부산', '서울', '원주'], dtype=object)

# %%
c = {}
for i in range(len(code)):
    #c[i] = code[i]
    c[code[i]] = i
    
c
# Out:
# {'부산': 0, '서울': 1, '원주': 2}

# %%
data['코드'] = data.지역.map(c)
data
# Out:
#    국어  영어  지역  코드
# 0  99  88  서울   1
# 1  76  89  부산   0
# 2  86  95  원주   2
# 3  63  76  서울   1

# %%
data2 = data.copy()
data2['코드'] = data.지역.map(lambda x: list(code).index(x))
data2
# Out:
#    국어  영어  지역  코드
# 0  99  88  서울   1
# 1  76  89  부산   0
# 2  86  95  원주   2
# 3  63  76  서울   1

# %%
X = data[['국어','영어','코드']].values
X
# Out:
# array([[99, 88,  1],
#        [76, 89,  0],
#        [86, 95,  2],
#        [63, 76,  1]], dtype=int64)

# %%
X = X / [100,100,1]
X
# Out:
# array([[0.99, 0.88, 1.  ],
#        [0.76, 0.89, 0.  ],
#        [0.86, 0.95, 2.  ],
#        [0.63, 0.76, 1.  ]])

# %%
plt.scatter(X[:,0], X[:,1], c=X[:,2])

# %%
data = pd.DataFrame([['홍길동',99,'1999/1/1'],
                     ['장길산',88,'1987/3/1'],
                     ['둘리',51,'2005/5/5']],
                   columns=['이름','성적','생일'])
data
# Out:
#     이름  성적        생일
# 0  홍길동  99  1999/1/1
# 1  장길산  88  1987/3/1
# 2   둘리  51  2005/5/5

# %%
pd.to_datetime(data.생일)
# Out:
# 0   1999-01-01
# 1   1987-03-01
# 2   2005-05-05
# Name: 생일, dtype: datetime64[ns]

# %%
pd.to_datetime(['1/1/2021', '1/31/2021'])
# Out:
# DatetimeIndex(['2021-01-01', '2021-01-31'], dtype='datetime64[ns]', freq=None)

# %%
data['날자'] = pd.to_datetime(data.생일)
data
# Out:
#     이름  성적        생일         날자
# 0  홍길동  99  1999/1/1 1999-01-01
# 1  장길산  88  1987/3/1 1987-03-01
# 2   둘리  51  2005/5/5 2005-05-05

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3 entries, 0 to 2
# Data columns (total 4 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   이름      3 non-null      object
#  1   성적      3 non-null      int64
#  2   생일      3 non-null      object
#  3   날자      3 non-null      datetime64[ns]
# dtypes: datetime64[ns](1), int64(1), object(2)
# memory usage: 224.0+ bytes

# %%
pd.to_datetime('2021:07:21', format='%Y:%m:%d')
# Out:
# Timestamp('2021-07-21 00:00:00')

# %%
pd.to_datetime('2021/07/21 13:21:22', format='%Y/%m/%d %H:%M:%S')
# Out:
# Timestamp('2021-07-21 13:21:22')

# %%
subway = pd.read_csv('CARD_SUBWAY_MONTH_202106.csv')
subway
# Out:
#            사용일자  노선명            역명  승차총승객수  하차총승객수      등록일자  기타
# 0      20210601  3호선            신사   28955   30583  20210604 NaN
# 1      20210601  3호선            잠원    4780    4656  20210604 NaN
# 2      20210601  3호선         고속터미널   33986   32532  20210604 NaN
# 3      20210601  3호선    교대(법원.검찰청)   14136    9362  20210604 NaN
# 4      20210601  3호선  남부터미널(예술의전당)   27604   28821  20210604 NaN
# ...         ...  ...           ...     ...     ...       ...  ..
# 18030  20210630  1호선           서울역   42545   39641  20210703 NaN
# 18031  20210630  8호선            신흥    4343    4713  20210703 NaN
# 18032  20210630  분당선            망포   14451   13503  20210703 NaN
# 18033  20210630  분당선          매탄권선    5121    4907  20210703 NaN
# 18034  20210630  분당선          수원시청   12344   13336  20210703 NaN
#
# [18035 rows x 7 columns]

# %%
subway.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 18035 entries, 0 to 18034
# Data columns (total 7 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   사용일자    18035 non-null  int64
#  1   노선명     18035 non-null  object
#  2   역명      18035 non-null  object
#  3   승차총승객수  18035 non-null  int64
#  4   하차총승객수  18035 non-null  int64
#  5   등록일자    18035 non-null  int64
#  6   기타      0 non-null      float64
# dtypes: float64(1), int64(4), object(2)
# memory usage: 986.4+ KB

# %%
pd.to_datetime(subway.사용일자, format='%Y%m%d')
# Out:
# 0       2021-06-01
# 1       2021-06-01
# 2       2021-06-01
# 3       2021-06-01
# 4       2021-06-01
#            ...
# 18030   2021-06-30
# 18031   2021-06-30
# 18032   2021-06-30
# 18033   2021-06-30
# 18034   2021-06-30
# Name: 사용일자, Length: 18035, dtype: datetime64[ns]

# %%
subway['날자'] = pd.to_datetime(subway.사용일자, format='%Y%m%d')
subway
# Out:
#            사용일자  노선명            역명  승차총승객수  하차총승객수      등록일자  기타         날자
# 0      20210601  3호선            신사   28955   30583  20210604 NaN 2021-06-01
# 1      20210601  3호선            잠원    4780    4656  20210604 NaN 2021-06-01
# 2      20210601  3호선         고속터미널   33986   32532  20210604 NaN 2021-06-01
# 3      20210601  3호선    교대(법원.검찰청)   14136    9362  20210604 NaN 2021-06-01
# 4      20210601  3호선  남부터미널(예술의전당)   27604   28821  20210604 NaN 2021-06-01
# ...         ...  ...           ...     ...     ...       ...  ..        ...
# 18030  20210630  1호선           서울역   42545   39641  20210703 NaN 2021-06-30
# 18031  20210630  8호선            신흥    4343    4713  20210703 NaN 2021-06-30
# 18032  20210630  분당선            망포   14451   13503  20210703 NaN 2021-06-30
# 18033  20210630  분당선          매탄권선    5121    4907  20210703 NaN 2021-06-30
# 18034  20210630  분당선          수원시청   12344   13336  20210703 NaN 2021-06-30
#
# [18035 rows x 8 columns]

# %%
subway['연도'] = subway.날자.dt.year
subway['월'] = subway.날자.dt.month
subway['일'] = subway.날자.dt.day
subway['요일'] = subway.날자.dt.dayofweek
subway
# Out:
#            사용일자  노선명            역명  승차총승객수  하차총승객수      등록일자  기타         날자  \
# 0      20210601  3호선            신사   28955   30583  20210604 NaN 2021-06-01
# 1      20210601  3호선            잠원    4780    4656  20210604 NaN 2021-06-01
# 2      20210601  3호선         고속터미널   33986   32532  20210604 NaN 2021-06-01
# 3      20210601  3호선    교대(법원.검찰청)   14136    9362  20210604 NaN 2021-06-01
# 4      20210601  3호선  남부터미널(예술의전당)   27604   28821  20210604 NaN 2021-06-01
# ...         ...  ...           ...     ...     ...       ...  ..        ...
# 18030  20210630  1호선           서울역   42545   39641  20210703 NaN 2021-06-30
# 18031  20210630  8호선            신흥    4343    4713  20210703 NaN 2021-06-30
# 18032  20210630  분당선            망포   14451   13503  20210703 NaN 2021-06-30
# 18033  20210630  분당선          매탄권선    5121    4907  20210703 NaN 2021-06-30
# 18034  20210630  분당선          수원시청   12344   13336  20210703 NaN 2021-06-30
#
#          연도  월   일  요일
# 0      2021  6   1   1
# 1      2021  6   1   1
# 2      2021  6   1   1
# 3      2021  6   1   1
# 4      2021  6   1   1
# ...     ... ..  ..  ..
# 18030  2021  6  30   2
# 18031  2021  6  30   2
# 18032  2021  6  30   2
# 18033  2021  6  30   2
# 18034  2021  6  30   2
#
# [18035 rows x 12 columns]

# %%
code = {0:'월', 1:'화', 2:'수', 3:'목', 4:'금', 5: '토', 6:'일'}
code
# Out:
# {0: '월', 1: '화', 2: '수', 3: '목', 4: '금', 5: '토', 6: '일'}

# %%
subway.요일.map(code)
# Out:
# 0        화
# 1        화
# 2        화
# 3        화
# 4        화
#         ..
# 18030    수
# 18031    수
# 18032    수
# 18033    수
# 18034    수
# Name: 요일, Length: 18035, dtype: object

# %%
subway['요일명'] = subway.요일.map(code)
subway
# Out:
#            사용일자  노선명            역명  승차총승객수  하차총승객수      등록일자  기타         날자  \
# 0      20210601  3호선            신사   28955   30583  20210604 NaN 2021-06-01
# 1      20210601  3호선            잠원    4780    4656  20210604 NaN 2021-06-01
# 2      20210601  3호선         고속터미널   33986   32532  20210604 NaN 2021-06-01
# 3      20210601  3호선    교대(법원.검찰청)   14136    9362  20210604 NaN 2021-06-01
# 4      20210601  3호선  남부터미널(예술의전당)   27604   28821  20210604 NaN 2021-06-01
# ...         ...  ...           ...     ...     ...       ...  ..        ...
# 18030  20210630  1호선           서울역   42545   39641  20210703 NaN 2021-06-30
# 18031  20210630  8호선            신흥    4343    4713  20210703 NaN 2021-06-30
# 18032  20210630  분당선            망포   14451   13503  20210703 NaN 2021-06-30
# 18033  20210630  분당선          매탄권선    5121    4907  20210703 NaN 2021-06-30
# 18034  20210630  분당선          수원시청   12344   13336  20210703 NaN 2021-06-30
#
#          연도  월   일  요일 요일명
# 0      2021  6   1   1   화
# 1      2021  6   1   1   화
# 2      2021  6   1   1   화
# 3      2021  6   1   1   화
# 4      2021  6   1   1   화
# ...     ... ..  ..  ..  ..
# 18030  2021  6  30   2   수
# 18031  2021  6  30   2   수
# 18032  2021  6  30   2   수
# 18033  2021  6  30   2   수
# 18034  2021  6  30   2   수
#
# [18035 rows x 13 columns]
