# %% [markdown]
# ## 15일차 강의 (2021.7.23)
# # 머신러닝

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# ### 사전 연습문제
# - 아이리스 데이터는 속성이 4개이다. 속성들 간에 산점도를 총 6개를 그릴수 있다.
# - 6개의 산점도를 그리시오.
# - 위 산점도에서 각 품종별로 색을 다르게 표시해 보시오.

# %% [markdown]
# - 샘플 하나하나를 4차원 공간(속성이 4개이므로)의 점들로 볼 수 있다.
# - 첫번째 샘플과 나머지 샘플들간의 거리를 구해보시오.
# - 모든 점들간의 거리를 구하면 150x150 개의 값을 구할 수 있다. 이를 계산해 보시오.
# > 같은 크기의 그림 2장이 있다. 이 두 그림의 거리를 잴수 있을까?

# %%
## 거리 공식
x1 = np.array([1,2,3,4])
x2 = np.array([0,3,2,2])
distance = np.sqrt(((x1-x2)**2).sum())
distance
# Out:
# 2.6457513110645907

# %%
x1 = X[0]
x2 = X[1]
distance = np.sqrt(((x1-x2)**2).sum())
distance
# Out:
# 0.5385164807134502

# %%
np.sqrt(((X - x1)**2).sum(axis=1))
# Out:
# array([0.        , 0.53851648, 0.50990195, 0.64807407, 0.14142136,
#        0.6164414 , 0.51961524, 0.17320508, 0.92195445, 0.46904158,
#        0.37416574, 0.37416574, 0.59160798, 0.99498744, 0.88317609,
#        1.1045361 , 0.54772256, 0.1       , 0.74161985, 0.33166248,
#        0.43588989, 0.3       , 0.64807407, 0.46904158, 0.59160798,
#        0.54772256, 0.31622777, 0.14142136, 0.14142136, 0.53851648,
#        0.53851648, 0.38729833, 0.6244998 , 0.80622577, 0.46904158,
#        0.37416574, 0.41231056, 0.46904158, 0.8660254 , 0.14142136,
#        0.17320508, 1.34907376, 0.76811457, 0.45825757, 0.6164414 ,
#        0.59160798, 0.36055513, 0.58309519, 0.3       , 0.2236068 ,
#        4.00374824, 3.61662826, 4.16413256, 3.09354166, 3.79209705,
#        3.41613817, 3.78549865, 2.34520788, 3.74966665, 2.88790582,
#        2.70370117, 3.22800248, 3.14642654, 3.7       , 2.58069758,
#        3.62767143, 3.43511281, 3.00998339, 3.76828874, 2.88270706,
# ...

# %%
n2n = np.sqrt(((X.reshape(150,1,4) - X)**2).sum(axis=2))
n2n.shape
# Out:
# (150, 150)

# %%
plt.imshow(n2n, cmap='gray_r')
plt.colorbar()

# %%
data = pd.read_csv('iris.csv')

# %%
X = pd.read_csv('iris.csv').iloc[:,:4].values
y = np.array([0]*50 + [1]*50 + [2]*50)

# %%
X.shape, y.shape
# Out:
# ((150, 4), (150,))

# %%
plt.scatter(X[:,2], X[:,3], c=y)
plt.xlabel(data.columns[2])
plt.ylabel(data.columns[3])
plt.colorbar()
#plt.scatter(X[:,0], X[:,1], c=['r']*50+['g']*50+['b']*50)

# %%
n=0
plt.figure(figsize=[12,8])
for i in range(3):
    for j in range(i+1,4):
        plt.subplot(2,3,n+1)
        plt.scatter(X[:,i], X[:,j], c=y)
        plt.xlabel(data.columns[i])
        plt.ylabel(data.columns[j])
        n += 1
